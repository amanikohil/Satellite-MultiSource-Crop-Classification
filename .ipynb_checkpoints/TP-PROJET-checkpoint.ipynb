# %% [markdown]
# # Part 1: Base Classification Model - Sentinel-2 Preprocessing

# %%
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
import geopandas as gpd

# %%
import rasterio
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 import rasterio
#
# ModuleNotFoundError: No module named 'rasterio'

# %% [markdown]
# # Step 1: Load Sentinel-2 Bands (.jp2)

# %%
# Example Sentinel-2 bands for a single scene
bands = {
    'B02': 'path_to_B02.jp2',  # Blue
    'B03': 'path_to_B03.jp2',  # Green
    'B04': 'path_to_B04.jp2',  # Red
    'B08': 'path_to_B08.jp2',  # NIR
}

# %%
band_arrays = {}
for band_name, filepath in bands.items():
    with rasterio.open(filepath) as src:
        band_arrays[band_name] = src.read(1).astype(float)
        profile = src.profile  # Keep georeferencing info if needed
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 band_arrays = {}
#       2 for band_name, filepath in bands.items():
# ----> 3     with rasterio.open(filepath) as src:
#       4         band_arrays[band_name] = src.read(1).astype(float)
#       5         profile = src.profile  # Keep georeferencing info if needed
#
# NameError: name 'rasterio' is not defined
